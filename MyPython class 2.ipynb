# %% [markdown]
# #operator#

# %% [markdown]
# #Arithmatic operator#

# %%
#+
9+5
# Out:
# 14

# %%
#operator
#Arithmatic operator
#-
9-5
# Out:
# 4

# %%
#operator
#Arithmatic operator
#*
9*5
# Out:
# 45

# %%
#operator
#Arithmatic operator
#/
9/2
# Out:
# 4.5

# %%
#modulo(gives back reminder)
9%2
# Out:
# 1

# %%
9%3
# Out:
# 0

# %%
#floor division // (take quotient)
18//4
# Out:
# 4

# %%
6//4
# Out:
# 1

# %%
#exponential operation
5**2
# Out:
# 25

# %%
2**3
# Out:
# 8

# %% [markdown]
# #relational operator#
# #<,<=,>,>=,==,!=

# %%
9>2
# Out:
# True

# %%
5<3
# Out:
# False

# %%
7==7
# Out:
# True

# %%
7!=7
# Out:
# False

# %% [markdown]
# #Logical Operator#
#
#
# #and,or,not

# %%
0 and 0
# Out:
# 0

# %%
1 or 1
# Out:
# 1

# %%
1 and 1
# Out:
# 1

# %%
1 and 0
# Out:
# 0

# %%
not 1
# Out:
# False

# %%
not 0
# Out:
# True

# %% [markdown]
# #Assigment Operator#(=,+=,*=,**=,%=,/=,//=,-=)

# %%
a=14
a
# Out:
# 14

# %%
a=14
a+=2
a
# Out:
# 16

# %%
a=9
a+=3
a
# Out:
# 12

# %%
a=9
a*=3
a
# Out:
# 27

# %%
a=9
a**=3
a
# Out:
# 729

# %%
a

# %% [markdown]
# #Membership Operator# case sensitive

# %%
'p' in 'Python'
# Out:
# False

# %%
'r' not in 'cat'
# Out:
# True

# %%
'r' not in 'rat'
# Out:
# False

# %%
#Print#

# %%
print(True)
# Out:
# True

# %%
print(9,9.0,'py',False)
# Out:
# 9 9.0 py False

# %%
print(8)
# Out:
# 8

# %%
print(9,9.0,'py',False,sep=',')
# Out:
# 9,9.0,py,False

# %%
print('learn')
print('python')
# Out:
# learn
# python

# %%
print('learn', end=' ')
print('python')
# Out:
# learn python

# %% [markdown]
# #Indexing#

# %% [markdown]
# s='python'
# p 0
# y 1
# t 2
# h 3
# o 4
# n 5

# %%
s='python'
s[0]
# Out:
# 'p'

# %% [markdown]
# #Negative indexing#

# %% [markdown]
# s='python'
# p -6
# y -5
# t -4
# h -3
# o -2
# n -1

# %%
s[-1]
# Out:
# 'n'

# %%
s[-6]
# Out:
# 'p'
