# %%
'python'
# Out:
# 'python'

# %% [markdown]
# ##### My first Python #####
# a=2

# %% [raw]
# # write python #

# %%
# esc dd -> delete
# esc b -> add cell
# esc a -> add cell above
# esc b -> add cell below

# %%
5+3
# Out:
# 8

# %%
# a is a variable
a=1
# what is data type of a it will be int
type(a)
# Out:
# int

# %%
# a is a variable
a='67'
# what is data type of a it will be string
type(a)
# Out:
# str

# %%
# a is a variable
a=67.0
# what is data type of a it will be float
type(a)
# Out:
# float

# %%
# a is a variable
a='67.0'
# what is data type of a it will be string
type(a)
# Out:
# str

# %%
# a is a variable
a=True
# what is data type of a it will be bool(boolion)
type(a)
# Out:
# bool

# %%
# a is a variable
a=False
# what is data type of a it will be bool(boolion)
type(a)
# Out:
# bool

# %%
# a is a variable
a=5+7j
# what is data type of a it will be complex
type(a)
# Out:
# complex

# %%
#identifier
a=15
# a is the identifier
#need to follow some rules to identify identifier
# it should be alpha, alpha numerical a=1 or a1=1
# it should not start with number not 1=a
# no special character
# no special character except _ (underscore) -> _=1
# reserve notation we will use that particular notation for our specific work that we call keyword,
# we cant use  keyword as identifier

# %%
_=15

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a_1=9
a_1
# Out:
# 9
